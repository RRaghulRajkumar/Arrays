# %% [markdown]
# ## Contains Duplicate

# %% [markdown]
# ### Given an integer array nums, return true if any value appears at least twice in the array, and return false if every element is distinct.

# %% [markdown]
# Example 1:
#
# Input: nums = [1,2,3,1]
# Output: true

# %% [markdown]
# Example 2:
#
# Input: nums = [1,2,3,4]
# Output: false

# %% [markdown]
# Example 3:
#
# Input: nums = [1,1,1,3,3,4,3,2,4,2]
# Output: true

# %% [markdown]
# ![containduplicates.png](attachment:containduplicates.png)
